# %%
import matplotlib.pyplot as plt
import numpy as np
f=open("rtt_daily.csv","r")
next(f)
rtt={}
for l in f:
    row=l.split(",")
    rtt[row[0]]=float(row[1].strip())
f.close()
print(rtt)
# Out:
# {'00-04.xml': 64.99309524, '04-08.xml': 5.74952381, '08-12.xml': 10.07452381, '12-16.xml': 1.73, '16-20.xml': 7.84825, '20-00.xml': 31.28684211}

# %%
plt.plot([i for i in  range(len(rtt))],[rtt[i] for i in  rtt])
plt.xticks([i for i in  range(len(rtt))],[i.replace(".xml","") for i in  rtt])
plt.xlim(0,6)
plt.ylabel("mean rtt")
plt.xlabel("time (in 24 hrs)")
plt.show()
